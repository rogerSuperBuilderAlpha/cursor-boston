# %% [markdown]
# # AI Bank Marketing
#
# This notebook sketches an AI-assisted workflow for bank marketers: **who** to contact, **when** to reach out, **how likely** a customer is to convert, and **why** the model suggests an action. Replace sample data and models with your own datasets and policies before production use.

# %%
import pandas as pd

# Example: customer features (synthetic placeholders — use your CRM / warehouse data)
customers = pd.DataFrame({
    "customer_id": ["c001", "c002", "c003"],
    "days_since_last_contact": [120, 14, 45],
    "recent_web_visits": [0, 3, 1],
    "product_interest_score": [0.2, 0.85, 0.4],
})
customers

# %% [markdown]
# ## Next steps
#
# - Train or calibrate a conversion model on labeled outcomes.
# - Add policy rules (frequency caps, consent, channel preferences).
# - Use SHAP, partial dependence, or rule lists to document **why** each recommendation was made.
